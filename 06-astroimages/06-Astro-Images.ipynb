# %% [markdown]
# # Images in Astronomy

# %% [markdown]
# In this lesson we are going to look at aspects of processing and viewing images specific to Astronomy and Solar Astronomy. By the end of this lesson you should understand:
#
# * Projected Coordinate Systems in Images
# * World Coordinate Systems
# * Using WCS to calculate coordinates in images
# * Plotting images with WCS in images
# * Using SunPy Map

# %% [markdown]
# ## Projected Coordinate Systems

# %% [markdown]
# When taking images of the sky, we are projecting the spherical celestial coordinate system onto a 2-dimensional plane, which means that there is no simple linear relation between pixel coordinates and celestial coordinates
#
# There are multiple coordinate systems used to describe the locations in 2D and 3D space for both Astronomy and Solar Physics. We shall use a couple of these systems here as examples but if you want to know more about them there are many of resources avalible.

# %% [markdown]
# ### World Coordinate System

# %% [markdown]
# The FITS files have a standard for describing the physical coordinate system associated with imaging data, this is called the world coordinate system or WCS, sometimes the specific FITS version of this is referred to as FITS-WCS.
#
# There are multiple papers describing the FITS-WCS standard for various types of data, there is a list here: http://fits.gsfc.nasa.gov/fits_wcs.html

# %% [markdown]
# As you learned in the previous lesson we can load FITS files with Astropy. To demonstrate a simple example of a FITS file with FITS-WCS information in the header we shall use an image from SunPy:

# %%
import sunpy.data
sunpy.data.download_sample_data()
# Out:
# Downloading sample files to /home/gruel/sunpy/data/sample_data
# Downloading http://data.sunpy.org/sample-data/hsi_calib_ev_20020220_1106_20020220_1106_25_40.fits [Done]
# Downloading http://data.sunpy.org/sample-data/swap_lv1_20120101_001607.fits [Done]
# Downloading http://data.sunpy.org/sample-data/ssw_cutout_20121030_153001_AIA_94_.fts [Done]
# Downloading http://data.sunpy.org/sample-data/eit_l1_20020625_100011.fits [Done]
# Downloading http://data.sunpy.org/sample-data/hsi_image_20101016_191218.fits [Done]
# Downloading http://data.sunpy.org/sample-data/BIR_20110922_103000_01.fit [Done]
# Downloading http://data.sunpy.org/sample-data/AIA20110319_105400_0171.fits [Done]
# Downloading http://data.sunpy.org/sample-data/aia.lev1.193A_2013-09-21T16_00_06.84Z.image_lev1.fits.zip [Done]
# Unpacking: aia.lev1.193A_2013-09-21T16_00_06.84Z.image_lev1.fits
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# <ipython-input-6-d5410124894a> in <module>()
#       1 import sunpy.data
# ----> 2 sunpy.data.download_sample_data()
#       3 from sunpy.data.sample import AIA_171_ROLL_IMAGE
#
# /home/gruel/.conda/envs/py2/lib/python2.7/site-packages/sunpy/data/_sample.py in download_sample_data(progress, overwrite)
#      72         for base_url in _base_urls:
#      73             full_file_name = file_name[0] + file_name[1]
# ---> 74             if url_exists(os.path.join(base_url, full_file_name)):
#      75                 f = download_file(os.path.join(base_url, full_file_name))
#      76                 real_name, ext = os.path.splitext(full_file_name)
#
# /home/gruel/.conda/envs/py2/lib/python2.7/site-packages/sunpy/util/net.py in url_exists(url, timeout)
#     196     """
#     197     try:
# --> 198         urllib2.urlopen(url, timeout=timeout)
#     199     except urllib2.HTTPError:
#     200         return False
#
# /home/gruel/.conda/envs/py2/lib/python2.7/urllib2.pyc in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     152     else:
#     153         opener = _opener
# --> 154     return opener.open(url, data, timeout)
#     155
#     156 def install_opener(opener):
#
# /home/gruel/.conda/envs/py2/lib/python2.7/urllib2.pyc in open(self, fullurl, data, timeout)
#     429             req = meth(req)
#     430
# --> 431         response = self._open(req, data)
#     432
#     433         # post-process response
#
# /home/gruel/.conda/envs/py2/lib/python2.7/urllib2.pyc in _open(self, req, data)
#     447         protocol = req.get_type()
#     448         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 449                                   '_open', req)
#     450         if result:
#     451             return result
#
# /home/gruel/.conda/envs/py2/lib/python2.7/urllib2.pyc in _call_chain(self, chain, kind, meth_name, *args)
#     407             func = getattr(handler, meth_name)
#     408
# --> 409             result = func(*args)
#     410             if result is not None:
#     411                 return result
#
# /home/gruel/.conda/envs/py2/lib/python2.7/urllib2.pyc in http_open(self, req)
#    1225
#    1226     def http_open(self, req):
# -> 1227         return self.do_open(httplib.HTTPConnection, req)
#    1228
#    1229     http_request = AbstractHTTPHandler.do_request_
#
# /home/gruel/.conda/envs/py2/lib/python2.7/urllib2.pyc in do_open(self, http_class, req, **http_conn_args)
#    1198         else:
#    1199             try:
# -> 1200                 r = h.getresponse(buffering=True)
#    1201             except TypeError: # buffering kw not supported
#    1202                 r = h.getresponse()
#
# /home/gruel/.conda/envs/py2/lib/python2.7/httplib.pyc in getresponse(self, buffering)
#    1134
#    1135         try:
# -> 1136             response.begin()
#    1137             assert response.will_close != _UNKNOWN
#    1138             self.__state = _CS_IDLE
#
# /home/gruel/.conda/envs/py2/lib/python2.7/httplib.pyc in begin(self)
#     451         # read until we get a non-100 response
#     452         while True:
# --> 453             version, status, reason = self._read_status()
#     454             if status != CONTINUE:
#     455                 break
#
# /home/gruel/.conda/envs/py2/lib/python2.7/httplib.pyc in _read_status(self)
#     407     def _read_status(self):
#     408         # Initialize with Simple-Response defaults
# --> 409         line = self.fp.readline(_MAXLINE + 1)
#     410         if len(line) > _MAXLINE:
#     411             raise LineTooLong("header line")
#
# /home/gruel/.conda/envs/py2/lib/python2.7/socket.pyc in readline(self, size)
#     478             while True:
#     479                 try:
# --> 480                     data = self._sock.recv(self._rbufsize)
#     481                 except error, e:
#     482                     if e.args[0] == EINTR:
#
# timeout: timed out

# %%
from sunpy.data.sample import AIA_171_ROLL_IMAGE

# %%
from astropy.io import fits

# %%
#hdulist = fits.open('h_n4571_f555_mosaic.fits.gz')
hdulist = fits.open(AIA_171_ROLL_IMAGE)

# %%
type(hdulist)
hdulist.info()
# Out:
# Filename: /home/gruel/sunpy/data/sample_data/aiacalibim5.fits.gz
# No.    Name         Type      Cards   Dimensions   Format
# 0    PRIMARY     PrimaryHDU     188   (4096, 4096)   int16

# %%
hdu = hdulist[0]

# %%
hdu.header
# Out:
# WARNING: VerifyWarning: Verification reported errors: [astropy.io.fits.verify]
# WARNING:astropy:VerifyWarning: Verification reported errors:
# WARNING: VerifyWarning: Card 'OSCNMEAN' is not FITS standard (invalid value string: 'nan').  Fixed 'OSCNMEAN' card to meet the FITS standard. [astropy.io.fits.verify]
# WARNING:astropy:VerifyWarning: Card 'OSCNMEAN' is not FITS standard (invalid value string: 'nan').  Fixed 'OSCNMEAN' card to meet the FITS standard.
# WARNING: VerifyWarning: Note: PyFITS uses zero-based indexing.
#  [astropy.io.fits.verify]
# WARNING:astropy:VerifyWarning: Note: PyFITS uses zero-based indexing.
#
# WARNING: VerifyWarning: Card 'OSCNRMS' is not FITS standard (invalid value string: 'nan').  Fixed 'OSCNRMS' card to meet the FITS standard. [astropy.io.fits.verify]
# WARNING:astropy:VerifyWarning: Card 'OSCNRMS' is not FITS standard (invalid value string: 'nan').  Fixed 'OSCNRMS' card to meet the FITS standard.
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                   16 / number of bits per data pixel
# NAXIS   =                    2 / number of data axes
# NAXIS1  =                 4096 / length of data axis 1
# NAXIS2  =                 4096 / length of data axis 2
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# BLD_VERS= 'V8R4X'
# LVL_NUM = 1.000000
# T_REC   = '2014-04-09T06:00:14Z'
# TRECSTEP= 1.000000
# TRECEPOC= '1977.01.01_00:00:00_TAI'
# TRECROUN=                    1
# ORIGIN  = 'SDO/JSOC-SDP'
# DATE    = '2014-04-13T04:32:51'
# TELESCOP= 'SDO/AIA'
# INSTRUME= 'AIA_3'
# DATE-OBS= '2014-04-09T06:00:12.97'
# T_OBS   = '2014-04-09T06:00:14.47Z'
# CAMERA  =                    3
# IMG_TYPE= 'LIGHT'
# EXPTIME = 2.999649
# EXPSDEV = 0.000108
# INT_TIME= 3.273438
# WAVELNTH=                  171
# WAVEUNIT= 'angstrom'
# WAVE_STR= '171_THIN'
# FSN     =             86616997
# FID     =                    0
# QUALLEV0=               131072
# QUALITY =               393216
# TOTVALS =             16777216
# DATAVALS=             16777216
# MISSVALS=                    0
# PERCENTD= 100.00
# DATAMIN =                   -5
# DATAMAX =                16383
# DATAMEDN=                  223
# DATAMEAN= 364.16
# DATARMS = 518.09
# DATASKEW= 4.14
# DATAKURT= 29.55
# DATACENT= 599.62
# DATAP01 = 0.00
# DATAP10 = 13.00
# DATAP25 = 44.00
# DATAP75 = 460.00
# DATAP90 = 853.00
# DATAP95 = 1242.00
# DATAP98 = 1952.00
# DATAP99 = 2582.00
# NSATPIX =                    5
# OSCNMEAN= 'nan     '
# OSCNRMS = 'nan     '
# FLAT_REC= 'aia.flatfield[:#237]'
# NSPIKES =                 2594
# CTYPE1  = 'HPLN-TAN'
# CUNIT1  = 'arcsec'
# CRVAL1  = 0.000000
# CDELT1  = 0.599489
# CRPIX1  = 2053.459961
# CTYPE2  = 'HPLT-TAN'
# CUNIT2  = 'arcsec'
# CRVAL2  = 0.000000
# CDELT2  = 0.599489
# CRPIX2  = 2047.880005
# CROTA2  = -44.980717
# R_SUN   = 1597.968506
# MPO_REC = 'sdo.master_pointing[:#656]'
# INST_ROT= 0.019327
# IMSCL_MP= 0.599489
# X0_MP   = 2052.459961
# Y0_MP   = 2046.880005
# ASD_REC = 'sdo.lev0_asd_0004[:#33068668]'
# SAT_Y0  = 2.132145
# SAT_Z0  = 11.665024
# SAT_ROT = -45.000042
# ACS_MODE= 'SCIENCE'
# ACS_ECLP= 'NO'
# ACS_SUNP= 'YES'
# ACS_SAFE= 'NO'
# ACS_CGT = 'GT3'
# ORB_REC = 'sdo.fds_orbit_vectors[2014.04.09_06:00:00_UTC]'
# DSUN_REF= 149597870691.0
# DSUN_OBS= 149860273889.04
# RSUN_REF= 696000000.0
# RSUN_OBS= 957.964493
# GAEX_OBS= -41359534.22
# GAEY_OBS= 1348628.68
# GAEZ_OBS= 8110652.84
# HAEX_OBS= -141600139801.20
# HAEY_OBS= -49066301953.67
# HAEZ_OBS= 10534221.35
# OBS_VR  = 769.968310
# OBS_VW  = 31508.369812
# OBS_VN  = 4513.872401
# CRLN_OBS= 335.085388
# CRLT_OBS= -6.047074
# CAR_ROT =                 2149
# HGLN_OBS= 0.000000
# HGLT_OBS= -6.047074
# ROI_NWIN=          -2147483648
# ROI_SUM =          -2147483648
# ROI_NAX1=          -2147483648
# ROI_NAY1=          -2147483648
# ROI_LLX1=          -2147483648
# ROI_LLY1=          -2147483648
# ROI_NAX2=          -2147483648
# ROI_NAY2=          -2147483648
# ROI_LLX2=          -2147483648
# ROI_LLY2=          -2147483648
# PIXLUNIT= 'DN'
# DN_GAIN = 17.700
# EFF_AREA= 2.360
# EFF_AR_V= 3.000
# TEMPCCD = -71.000
# TEMPGT  = 14.862
# TEMPSMIR= 35.851
# TEMPFPAD= 16.449
# ISPSNAME= 'aia.lev0_isp_0011'
# ISPPKTIM= '2014-04-09T06:00:07.51Z'
# ISPPKTVN= '001.197'
# AIVNMST =                  453
# AIMGOTS =           1775714449
# ASQHDR  =           2234100645
# ASQTNUM =                    2
# ASQFSN  =             86616997
# AIAHFSN =             86616989
# AECDELAY=                 1536
# AIAECTI =                    0
# AIASEN  =                    0
# AIFDBID =                  241
# AIMGOTSS=                 5698
# AIFCPS  =                   10
# AIFTSWTH=                    0
# AIFRMLID=                 3138
# AIFTSID =                49155
# AIHISMXB=                    0
# AIHIS192=                    0
# AIHIS348=                    0
# AIHIS604=                    0
# AIHIS860=                    0
# AIFWEN  =                  204
# AIMGSHCE=                 3000
# AECTYPE =                    2
# AECMODE = 'OPEN'
# AISTATE = 'OPEN'
# AIAECENF=                    1
# AIFILTYP=                    0
# AIMSHOBC= 54.723999
# AIMSHOBE= 68.695999
# AIMSHOTC= 40.492001
# AIMSHOTE= 25.504000
# AIMSHCBC= 3054.312012
# AIMSHCBE= 3068.204102
# AIMSHCTC= 3040.204102
# AIMSHCTE= 3025.291992
# AICFGDL1=                    0
# AICFGDL2=                    9
# AICFGDL3=                   73
# AICFGDL4=                  236
# AIFOENFL=                    1
# AIMGFSN =                   17
# AIMGTYP =                    0
# AIAWVLEN=                    7
# AIAGP1  =                    0
# AIAGP2  =                    0
# AIAGP3  =                    0
# AIAGP4  =                    0
# AIAGP5  =                    0
# AIAGP6  =                    0
# AIAGP7  =                    0
# AIAGP8  =                  777
# AIAGP9  =                  841
# AIAGP10 =                 1260
# AGT1SVY =                    7
# AGT1SVZ =                  -11
# AGT2SVY =                    1
# AGT2SVZ =                  -10
# AGT3SVY =                    3
# AGT3SVZ =                    1
# AGT4SVY =                   13
# AGT4SVZ =                  -42
# AIMGSHEN=                   13
# KEYWDDOC= 'http://www.lmsal.com/sdodocs/aiafitskeywords.pdf'
# RECNUM  =            135407475
# BLANK   =               -32768

# %%
hdu.data
# Out:
# array([[-1.,  1., -1., ..., -1., -1.,  1.],
#        [-1., -1.,  2., ...,  2., -1.,  0.],
#        [ 1., -1.,  0., ..., -1., -1., -1.],
#        ...,
#        [ 0.,  0., -1., ..., -3.,  1.,  2.],
#        [-1.,  1.,  0., ...,  2., -3.,  0.],
#        [ 1., -1.,  3., ...,  2.,  1.,  0.]], dtype=float32)

# %% [markdown]
# As you can see there are lots of keys in this and most other real world FITS headers. The ones we need to understand for FITS-WCS are:

# %% [markdown]
# Reference Pixel and Coordinate:

# %%
header = hdulist[0].header
print(header['CRVAL1'], header['CRVAL2'])
print(header['CRPIX1'], header['CRPIX2'])
# Out:
# (0.0, 0.0)
# (2053.459961, 2047.880005)

# %% [markdown]
# Pixel resolution (at the reference pixel):

# %%
print(header['CDELT1'], header['CDELT2'])
# Out:
# (0.599489, 0.599489)

# %% [markdown]
# Rotation angle, in degress (at the reference pixel):

# %%
print(header['CROTA2'])
# Out:
# -44.980717

# %% [markdown]
# Coordinate System and Projection:

# %%
print(header['CTYPE1'], header['CTYPE2'])
# Out:
# ('HPLN-TAN', 'HPLT-TAN')

# %% [markdown]
# <section class="objectives panel panel-success">
# <div class="panel-heading">
# <h2><span class="fa fa-pencil"></span> Keyword Extraction </h2>
# </div>
#
# Extract and print out the `TELESCOP` value from the header.
#
# Next, extract the `WAVELNTH` and `WAVEUNIT` values, use these to construct an astropy Quantity object for the wavelength of this image.

# %%
print(header['TELESCOP'])

# %%
print(header['WAVELNTH'], header['WAVEUNIT'])
import astropy.units as u

u.Unit('angstrom')

im_wav = header['WAVELNTH'] * u.Unit(header['WAVEUNIT'])
print(im_wav)

im_wav2 = u.Quantity(header['WAVELNTH'], u.Unit(header['WAVEUNIT']))
print(im_wav2)
# Out:
# (171, 'angstrom')
# 171.0 Angstrom
# 171.0 Angstrom

# %% [markdown]
# We could now sit down and work out how to convert from a pixel coordinate to a physical coordinate described by this header (Helioprojective).
#
# However, we can cheat and just use Astropy.

# %%
from astropy.wcs import WCS
wcs = WCS(header)
wcs
# Out:
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'HPLN-TAN'  'HPLT-TAN'
# CRVAL : 0.0  0.0
# CRPIX : 2053.459961  2047.880005
# NAXIS    : 4096 4096

# %% [markdown]
# We can convert from pixel to world coordinate:

# %%
wcs.all_pix2world([[300,300]], 0) #0 because we are doing python, if pixel from fortran change by 1
# Out:
# array([[  3.59587957e+02,   5.18354457e-04]])

# %% [markdown]
# Or back again:

# %%
wcs.all_world2pix([[  3.59587957e+02,   5.18354457e-04]], 0)
# Out:
# array([[ 300.00015266,  300.00015256]])

# %% [markdown]
# The last parameter to the two above examples is the 'origin' parameter. It is a flag that tells WCS if you indexes should be 0-based (like numpy) or 1-based (like FITS).
# Here we are using 0 as we want to convert to and from numpy indexes of the array.

# %% [markdown]
# <section class="objectives panel panel-success">
# <div class="panel-heading">
# <h2><span class="fa fa-pencil"></span> How large is the image? </h2>
# </div>
# <br/>
# To get a little practise using Astropy's WCS calculate the world coordinates of the following pixels:
# <code>
# [-500, 0]
# [500, 500]
# [0, 0]
# </code>
# <br/>
# </section>

# %%
wcs.all_pix2world([[-500,0], [500,500], [0,0]],0)
# Out:
# array([[  3.59458420e+02,   5.93474799e-02],
#        [  3.59635055e+02,   5.34208718e-04],
#        [  3.59517311e+02,   4.94572769e-04]])

# %% [markdown]
# ## Plotting with wcsaxes

# %% [markdown]
# In this section we are going to use the wcsaxes package to make WCS aware image plots.

# %%
import wcsaxes

# %% [markdown]
# For this example we are going to use a Hubble image.

# %%
from astropy.io import fits
hdulist = fits.open('h_n4571_f555_mosaic.fits.gz')
hdulist.info()
# Out:
# Filename: h_n4571_f555_mosaic.fits.gz
# No.    Name         Type      Cards   Dimensions   Format
# 0    PRIMARY     PrimaryHDU    1151   (4096, 4096)   float32

# %%
wcs = WCS(hdulist[0].header)

# %%
# %matplotlib nbagg
import matplotlib.pyplot as plt

# %%
ax = plt.subplot(111, projection=wcs)
ax.imshow(hdulist[0].data, cmap='gray', vmax=1000, interpolation='none', origin='lower'#ax.set_autoscale_on(False)

ax.plot(3000, 3000, 'o')
ax.plot(185.25, 14.23, 'o', transform=ax.get_transform('world'))

overlay = ax.get_coords_overlay('galactic')
overlay.grid(color='orange', linestyle='solid')
overlay['l'].set_axislabel("Galactic Longitude [degrees]")
overlay['b'].set_axislabel("Galactic Latitude [degrees]"))

#Note: press w on the image to go from world coordinate to pixels one.
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# This image now has physcial labels in the native coordinate system of the image. We can see what the coordinate system and projection of this image is using the 'CTYPE' header entries we saw earlier.

# %% [markdown]
# We can tell that this is in the FK5 coordinate system by the presence of a 'equinox' entry in the header:

# %%
hdulist[0].header['equinox']
# Out:
# 2000.0

# %% [markdown]
# There is also a quick way to generate an Astropy coordinate frame from a WCS object, which confirms this diagnosis.

# %%
from astropy.wcs.utils import wcs_to_celestial_frame
wcs_to_celestial_frame(wcs)
# Out:
# <FK5 Frame (equinox=2000.0)>

# %% [markdown]
# for more information on the very useful `astropy.coordinates` module see http://docs.astropy.org/en/stable/coordinates/

# %% [markdown]
# <section class="objectives panel panel-success">
# <div class="panel-heading">
# <h2><span class="fa fa-pencil"></span> Add some labels </h2>
# </div>
# <br/>
# Now we have a nice plot with physically meaningful ticks, we should label our axes.
# <br/>
#
# Add labels to the axes saying "Right Ascension [degrees]" and "Declination [degrees]"
# <br/>
#
# Also overlay a coordinate grid using:
# <code>ax.coords.grid()</code>
# Look up the documentation for this method to see what parameters you can specify.
# <br/>
# </section>

# %%
hdulist = fits.open('h_n4571_f555_mosaic.fits.gz')
wcs = WCS(hdulist[0].header)

# %matplotlib nbagg
import matplotlib.pyplot as plt

ax = plt.subplot(111, projection=wcs)
ax.imshow(hdulist[0].data, cmap='gray', vmax=1000, interpolation='none', origin='lower')
ax.set_ylabel("Declination [degrees]")
ax.set_xlabel("Right Ascension [degrees]")
ax.grid(color='w', linestyle='solid', alpha=0.5)
ax.coords.grid(True, 'lines')

ax.set_autoscale_on(False)

ax.plot(3000, 3000, 'o')
ax.plot(189.25, 14.23, 'o', transform=ax.get_transform('world'))

overlay = ax.get_coords_overlay('galactic')
overlay.grid(color='orange', linestyle='solid')
overlay['l'].set_axislabel("Galactic Longitude [degrees]")
overlay['b'].set_axislabel("Galactic Latitude [degrees]")
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# Now we have a nice plot, we can do a couple of things to plot.

# %% [markdown]
# ### Overplotting in Pixel Coordinates

# %% [markdown]
# ### Overplotting in World Coordinates

# %%
# Overplot in FK5 in Degrees

# %% [markdown]
# <section class="objectives panel panel-success">
# <div class="panel-heading">
# <h2><span class="fa fa-pencil"></span> Add some labels </h2>
# </div>
#
# Now overplot two lines on the image, one where you specified the line in pixel coordinates, and one where you specified the line in FK5 world coordinates.
#
# </section>

# %%
# Overplot in FK5 in Degrees

# %% [markdown]
# ###  Overplotting Another Coordinate System

# %% [markdown]
# ## SunPy Map

# %% [markdown]
# The SunPy Map class is a wrapper for solar images which makes some of the above opertations easier.

# %%
import sunpy.map
from sunpy.data.sample import AIA_171_ROLL_IMAGE

# %%
amap = sunpy.map.Map(AIA_171_ROLL_IMAGE)
amap.peek()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# This has done a quick plot of the test image `AIA_171_ROLL_IMAGE` using wcsaxes.
# If we want to customise the plot we use the `plot()` method.

# %%
import astropy.units as u
import matplotlib.pyplot as plt
# %matplotlib nbagg

# %%
amap = sunpy.map.Map(AIA_171_ROLL_IMAGE)

im = amap.plot()
ax = plt.gca()
ax.set_autoscale_on(False)

x = 500*u.arcsec
y = -300*u.arcsec

ax.plot(x.to(u.deg), y.to(u.deg), 'o', transform=ax.get_transform('world'))
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
amap.pixel_to_data(100*u.pix, 100*u.pix)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-113-f8a27f132cc5> in <module>()
# ----> 1 amap.pixel_to_data(100*u.pix, 100*u.pix)
#
# /home/gruel/.conda/envs/py2/lib/python2.7/site-packages/astropy/utils/decorators.py in pixel_to_data(self, x, y, origin)
#     677             name = func.__name__
#     678
# --> 679         func = make_function_with_signature(func, name=name, **wrapped_args)
#     680         func = functools.update_wrapper(func, wrapped, assigned=assigned,
#     681                                         updated=updated)
#
# /home/gruel/.conda/envs/py2/lib/python2.7/site-packages/astropy/units/decorators.pyc in wrapper(*func_args, **func_kwargs)
#     128             # Call the original function with any equivalencies in force.
#     129             with add_enabled_equivalencies(self.equivalencies):
# --> 130                 return wrapped_function(*func_args, **func_kwargs)
#     131
#     132         return wrapper
#
# /home/gruel/.conda/envs/py2/lib/python2.7/site-packages/sunpy/map/mapbase.py in pixel_to_data(self, x, y, origin)
#     603
#     604         # WCS always outputs degrees.
# --> 605         x *= u.deg
#     606         y *= u.deg
#     607
#
# TypeError: ufunc 'multiply' output (typecode 'O') could not be coerced to provided output parameter (typecode 'd') according to the casting rule ''same_kind''

# %%
sunpy.__version__
# Out:
# u'0.6.1'

# %% [markdown]
# <section class="objectives panel panel-success">
# <div class="panel-heading">
# <h2><span class="fa fa-pencil"></span> Rotate your Owl </h2>
# </div>
# Why is the Sun wonky?
#
# Use the [`rotate()`](http://docs.sunpy.org/en/stable/code_ref/map.html#sunpy.map.mapbase.GenericMap.rotate) method of SunPy Map to align the coordinate grid to the pixel grid in this sample image.
#
# Once you have run rotate, plot the resulting image, and compare with the one above.
# </section>
